# %%
import altair as alt
from vega_datasets import data

# for the notebook only (not for JupyterLab) run this command once per session
alt.renderers.enable('notebook')

#this is the iris dataset
iris = data.iris()

#displays data by category
alt.Chart(iris).mark_point().encode(
    x='petalLength',
    y='petalWidth',
    color='species'
)

# %%
import os
import pandas as pd

item_data = [] 
coll_data = []
for root,folders,files in os.walk('data'):
    for f in files:
        if 'item' in f:
            with open(root+'/'+f) as item_base:
                df = pd.read_csv(item_base)
                item_data.append(df)
        if 'collection' in f:
            with open(root+'/'+f) as coll_base:
                df = pd.read_csv(coll_base)
                coll_data.append(df)

# %%
item_data[0]
# Out:
#       Unnamed: 0      identifier  \
# 0              0  31735061656561
# 1              1  31735061659946
# 2              2  31735070075076
# 3              3  31735060482829
# 4              4  31735065151247
# ...          ...             ...
# 1882        1882  31735061544437
# 1883        1883  31735061538421
# 1884        1884  31735061543967
# 1885        1885  31735061544650
# 1886        1886  31735060483066
#
#                                                   title  creator date_created  \
# 0                      "Democracy Should Begin At Home"      NaN          NaN
# 1     "Delegate, Special Convention Communist Party,...      NaN          NaN
# 2     Political action; Political action (Milwaukee,...      NaN          NaN
# 3             Tenement Children Protest, New York City,      NaN   1934-02-26
# 4     Mine-Mill union; Mine Mill union; Sindicato; U...      NaN          NaN
# ...                                                 ...      ...          ...
# 1882                          "Washington Action" Flyer      NaN          NaN
# 1883              Women and Equality, By Margaret Cowl,      NaN      1935-02
# 1884  "Problems of Revolutionary Socialism", By Haim...      NaN          NaN
# 1885             "Constitution of the Socialist Party",      NaN         1983
# 1886                         "Stop the Bombing" Protest      NaN          NaN
#
#      date_issued                                          depositor   box  \
# 0            NaN                           University of Pittsburgh   2.0
# 1            NaN                           University of Pittsburgh   3.0
# 2     1912-02-17                           University of Pittsburgh   NaN
# 3            NaN                           University of Pittsburgh  13.0
# 4     1955-01-31  International Union of Mine, Mill, and Smelter...   NaN
# ...          ...                                                ...   ...
# 1882         NaN                           University of Pittsburgh  11.0
# 1883         NaN                           University of Pittsburgh   6.0
# 1884         NaN                           University of Pittsburgh  10.0
# 1885         NaN                           University of Pittsburgh  11.0
# 1886         NaN                           University of Pittsburgh  12.0
#
#       folder type_of_resource  \
# 0        5.0             text
# 1       18.0             text
# 2        NaN       text; text
# 3       62.0             text
# 4        NaN       text; text
# ...      ...              ...
# 1882   158.0             text
# 1883     5.0             text
# 1884   102.0             text
# 1885     1.0             text
# 1886    42.0      still image
#
#                                                   genre
# 0                                     archival document
# 1                                     archival document
# 2     newspaper; Newspapers.; Newspapers; Newspapers...
# 3                                     archival document
# 4     periodical; Periodicals.; Periodicals; Periodi...
# ...                                                 ...
# 1882                                  archival document
# 1883                                  archival document
# 1884                                  archival document
# 1885                                  archival document
# 1886                                  archival document
#
# [1887 rows x 11 columns]
